# %% [markdown]
# # 레슨 01 — 실습 문제
#
# `lecture.ipynb` 의 내용을 다 본 뒤 진행하는 학생용 문제 노트북이다. 이번 레슨은 NumPy 배열을 이용해 1차원 데이터와 간단한 2열 데이터를 읽고, 평균·중앙값·표준편차·마스크·분위수·간단한 결론까지 연결하는 것이 목표다.
#
# 모든 문제는 **직접 코드 셀을 채워서 실행**한다. 정답값은 이 노트북에 적지 않는다. 출력 형태와 힌트만 보고 스스로 계산한다.
#
# ## 통과 기준
#
# - 총 15문제 중 **12문제 이상** 정상 출력이면 통과.
# - 문제 1~5: 점수 데이터 기본 통계와 마스크.
# - 문제 6~9: 90일 걸음 데이터 분석.
# - 문제 10~11: 기온 데이터의 분위수와 조건 필터.
# - 문제 12~14: 가격 데이터와 데이터 간 관계 비교.
# - 문제 15: 계산 결과를 근거로 짧은 분석 결론 작성.
# - 코드가 돌아가더라도 결론이 데이터와 맞지 않으면 해당 문제는 미통과다.
#
# ## 0. 환경 셀
#
# 먼저 환경 감지 + NumPy import 셀을 실행한다. 이 셀이 정상 실행돼야 다음 문제가 가능하다.

# %%
import os
import numpy as np

IS_COLAB = "COLAB_GPU" in os.environ or "COLAB_TPU_ADDR" in os.environ
if IS_COLAB:
    DATA_BASE = "https://raw.githubusercontent.com/Kevin-innovation/jupyter-lecture/main/python-data-analysis/lectures/01/data"
else:
    DATA_BASE = "./data"

print("numpy:", np.__version__, "| data base:", DATA_BASE)

# %% [markdown]
# ---
#
# ## 문제 1 — 시험 점수 기본 요약
#
# `data/scores.csv` 를 불러와 200명의 점수를 NumPy 배열로 만든다.
#
# 다음 값을 출력한다.
#
# - 학생 수
# - 평균 점수
# - 중앙값 점수
# - 표준편차
# - 최고점과 최저점
#
# **기대 결과 형태**:
#
# ```
# 학생 수: ___명
# 평균: __.__점
# 중앙값: __.__점
# 표준편차: __.__
# 최고/최저: ___ / ___
# ```
#
# **빈칸 힌트**: 코드 셀의 `____`를 채우는 방식으로 접근한다. 사용할 데이터, 조건식, 함수명은 강의 노트의 같은 개념 예제를 찾아 직접 선택한다.

# %%
# 빈칸 가이드: 대상, 함수명, 조건식, 출력값을 직접 채우세요.
# 대상 = ____
# 결과 = ____(대상, ____)
# print(____)

# %% [markdown]
# ---
#
# ## 문제 2 — 90점 이상과 60점 미만 찾기
#
# 문제 1의 `scores` 배열을 사용한다. Boolean mask를 이용해 다음을 구한다.
#
# - 90점 이상 학생 수
# - 60점 미만 학생 수
# - 90점 이상 학생의 비율(%)
# - 60점 미만 학생의 비율(%)
#
# **기대 결과 형태**:
#
# ```
# 90점 이상: ___명 (__._%)
# 60점 미만: ___명 (__._%)
# ```
#
# **빈칸 힌트**: 코드 셀의 `____`를 채우는 방식으로 접근한다. 사용할 데이터, 조건식, 함수명은 강의 노트의 같은 개념 예제를 찾아 직접 선택한다.

# %%
# 빈칸 가이드: 대상, 함수명, 조건식, 출력값을 직접 채우세요.
# 대상 = ____
# 결과 = ____(대상, ____)
# print(____)

# %% [markdown]
# ---
#
# ## 문제 3 — 점수의 사분위수와 IQR
#
# `scores` 배열에서 Q1, Q2, Q3, IQR을 계산한다.
#
# 출력할 값:
#
# - Q1(25%)
# - Q2(50%, 중앙값)
# - Q3(75%)
# - IQR = Q3 - Q1
#
# **기대 결과 형태**:
#
# ```
# Q1: __.__
# Q2: __.__
# Q3: __.__
# IQR: __.__
# ```
#
# **빈칸 힌트**: 코드 셀의 `____`를 채우는 방식으로 접근한다. 사용할 데이터, 조건식, 함수명은 강의 노트의 같은 개념 예제를 찾아 직접 선택한다.

# %%
# 빈칸 가이드: 대상, 함수명, 조건식, 출력값을 직접 채우세요.
# 대상 = ____
# 결과 = ____(대상, ____)
# print(____)

# %% [markdown]
# ---
#
# ## 문제 4 — 점수 등급 분포 만들기
#
# `scores` 를 다음 5등급으로 나누어 각 인원 수를 출력한다.
#
# - A: 90점 이상
# - B: 80점 이상 90점 미만
# - C: 70점 이상 80점 미만
# - D: 60점 이상 70점 미만
# - F: 60점 미만
#
# 마지막에는 등급별 인원 합계가 전체 학생 수와 같은지 `assert` 로 확인한다.
#
# **기대 결과 형태**:
#
# ```
# A: ___명
# B: ___명
# C: ___명
# D: ___명
# F: ___명
# 합계: ___명
# ```
#
# **빈칸 힌트**: 코드 셀의 `____`를 채우는 방식으로 접근한다. 사용할 데이터, 조건식, 함수명은 강의 노트의 같은 개념 예제를 찾아 직접 선택한다.

# %%
# 빈칸 가이드: 대상, 함수명, 조건식, 출력값을 직접 채우세요.
# 대상 = ____
# 결과 = ____(대상, ____)
# print(____)

# %% [markdown]
# ---
#
# ## 문제 5 — 평균에서 멀리 떨어진 점수 찾기
#
# 점수를 표준화해서 z-score를 만든다.
#
# 해야 할 일:
#
# 1. `z = (scores - scores.mean()) / scores.std()` 를 계산한다.
# 2. `abs(z) >= 2` 인 점수를 찾는다.
# 3. 해당 학생의 인덱스와 점수를 출력한다.
# 4. 몇 명인지 출력한다.
#
# **기대 결과 형태**:
#
# ```
# 평균에서 2표준편차 이상 떨어진 학생 수: ___명
# 인덱스: [...]
# 점수: [...]
# ```
#
# **빈칸 힌트**: 코드 셀의 `____`를 채우는 방식으로 접근한다. 사용할 데이터, 조건식, 함수명은 강의 노트의 같은 개념 예제를 찾아 직접 선택한다.

# %%
# 빈칸 가이드: 대상, 함수명, 조건식, 출력값을 직접 채우세요.
# 대상 = ____
# 결과 = ____(대상, ____)
# print(____)

# %% [markdown]
# ---
#
# ## 문제 6 — 90일 걸음 데이터 기본 요약
#
# `data/daily_steps.csv` 를 불러와 `day` 와 `steps` 배열로 나눈다.
#
# 다음 값을 출력한다.
#
# - 총 일수
# - 총 걸음 수
# - 일평균 걸음 수
# - 걸음 수 표준편차
# - 가장 많이 걸은 날의 일자와 걸음 수
# - 가장 적게 걸은 날의 일자와 걸음 수
#
# **기대 결과 형태**:
#
# ```
# 총 일수: ___일
# 총 걸음: ___
# 일평균: ___ 보
# 표준편차: ___
# 최대일: ___일차, ___보
# 최소일: ___일차, ___보
# ```
#
# **빈칸 힌트**: 코드 셀의 `____`를 채우는 방식으로 접근한다. 사용할 데이터, 조건식, 함수명은 강의 노트의 같은 개념 예제를 찾아 직접 선택한다.

# %%
# 빈칸 가이드: 대상, 함수명, 조건식, 출력값을 직접 채우세요.
# 대상 = ____
# 결과 = ____(대상, ____)
# print(____)

# %% [markdown]
# ---
#
# ## 문제 7 — 10,000보 달성일과 5,000보 미만일
#
# `steps` 배열을 사용해 다음을 출력한다.
#
# - 10,000보 이상 걸은 날 수
# - 10,000보 이상 달성률(%)
# - 5,000보 미만 걸은 날 수
# - 5,000보 미만인 일자 리스트
#
# **기대 결과 형태**:
#
# ```
# 10,000보 이상: ___일 (__._%)
# 5,000보 미만: ___일
# 5,000보 미만 일자: [...]
# ```
#
# **빈칸 힌트**: 코드 셀의 `____`를 채우는 방식으로 접근한다. 사용할 데이터, 조건식, 함수명은 강의 노트의 같은 개념 예제를 찾아 직접 선택한다.

# %%
# 빈칸 가이드: 대상, 함수명, 조건식, 출력값을 직접 채우세요.
# 대상 = ____
# 결과 = ____(대상, ____)
# print(____)

# %% [markdown]
# ---
#
# ## 문제 8 — 월별 걸음 평균 비교
#
# 90일을 30일씩 나누어 1개월, 2개월, 3개월 평균 걸음 수를 비교한다.
#
# 해야 할 일:
#
# 1. `steps[:30]`, `steps[30:60]`, `steps[60:90]` 로 세 구간을 만든다.
# 2. 각 구간의 평균을 출력한다.
# 3. 1개월 대비 3개월 평균이 증가했는지 감소했는지 한 줄로 출력한다.
#
# **기대 결과 형태**:
#
# ```
# 1개월 평균: ___ 보
# 2개월 평균: ___ 보
# 3개월 평균: ___ 보
# 1개월 대비 3개월 변화: 증가/감소/유지
# ```
#
# **빈칸 힌트**: 코드 셀의 `____`를 채우는 방식으로 접근한다. 사용할 데이터, 조건식, 함수명은 강의 노트의 같은 개념 예제를 찾아 직접 선택한다.

# %%
# 빈칸 가이드: 대상, 함수명, 조건식, 출력값을 직접 채우세요.
# 대상 = ____
# 결과 = ____(대상, ____)
# print(____)

# %% [markdown]
# ---
#
# ## 문제 9 — 평일과 주말 걸음 비교
#
# `day` 를 사용해 평일/주말을 나누고 평균 걸음 수를 비교한다.
#
# 규칙:
#
# - `(day - 1) % 7` 값이 5 또는 6이면 주말로 본다.
# - 나머지는 평일로 본다.
#
# 출력할 값:
#
# - 평일 일수와 평균 걸음
# - 주말 일수와 평균 걸음
# - 평일 평균 - 주말 평균
#
# **빈칸 힌트**: 코드 셀의 `____`를 채우는 방식으로 접근한다. 사용할 데이터, 조건식, 함수명은 강의 노트의 같은 개념 예제를 찾아 직접 선택한다.

# %%
# 빈칸 가이드: 대상, 함수명, 조건식, 출력값을 직접 채우세요.
# 대상 = ____
# 결과 = ____(대상, ____)
# print(____)

# %% [markdown]
# ---
#
# ## 문제 10 — 90일 기온 기본 통계
#
# `data/temperatures.csv` 를 불러와 `temp_day`, `temp` 배열로 나눈다.
#
# 다음 값을 출력한다.
#
# - 기온 데이터 일수
# - 평균 기온
# - 중앙값 기온
# - 표준편차
# - 최저 기온과 최고 기온
# - Q1, Q2, Q3
# - IQR
#
# **빈칸 힌트**: 코드 셀의 `____`를 채우는 방식으로 접근한다. 사용할 데이터, 조건식, 함수명은 강의 노트의 같은 개념 예제를 찾아 직접 선택한다.

# %%
# 빈칸 가이드: 대상, 함수명, 조건식, 출력값을 직접 채우세요.
# 대상 = ____
# 결과 = ____(대상, ____)
# print(____)

# %% [markdown]
# ---
#
# ## 문제 11 — 기온 조건 필터 만들기
#
# `temp` 배열을 사용해 다음 조건의 일수를 출력한다.
#
# - 영하인 날(`temp < 0`)
# - Q3보다 더운 날(`temp > q3`)
# - 10°C 이상 15°C 이하인 날
# - 영하인 날의 일자 리스트
#
# **기대 결과 형태**:
#
# ```
# 영하: ___일, 일자 [...]
# Q3 초과: ___일
# 10~15도: ___일
# ```
#
# **빈칸 힌트**: 코드 셀의 `____`를 채우는 방식으로 접근한다. 사용할 데이터, 조건식, 함수명은 강의 노트의 같은 개념 예제를 찾아 직접 선택한다.

# %%
# 빈칸 가이드: 대상, 함수명, 조건식, 출력값을 직접 채우세요.
# 대상 = ____
# 결과 = ____(대상, ____)
# print(____)

# %% [markdown]
# ---
#
# ## 문제 12 — 상품 가격 기본 요약
#
# `data/product_prices.csv` 를 불러와 상품 가격 배열을 만든다.
#
# 다음 값을 출력한다.
#
# - 상품 수
# - 평균 가격
# - 중앙값 가격
# - 표준편차
# - 최고가와 최저가
# - 평균보다 비싼 상품 수
# - 중앙값보다 비싼 상품 수
#
# **빈칸 힌트**: 코드 셀의 `____`를 채우는 방식으로 접근한다. 사용할 데이터, 조건식, 함수명은 강의 노트의 같은 개념 예제를 찾아 직접 선택한다.

# %%
# 빈칸 가이드: 대상, 함수명, 조건식, 출력값을 직접 채우세요.
# 대상 = ____
# 결과 = ____(대상, ____)
# print(____)

# %% [markdown]
# ---
#
# ## 문제 13 — 가격 구간별 상품 수
#
# `prices` 배열을 다음 구간으로 나누어 상품 수를 출력한다.
#
# - 10,000원 미만
# - 10,000원 이상 20,000원 미만
# - 20,000원 이상 40,000원 미만
# - 40,000원 이상
#
# 마지막에는 네 구간의 합계가 전체 상품 수와 같은지 `assert` 로 확인한다.
#
# **기대 결과 형태**:
#
# ```
# 1만원 미만: ___개
# 1만원~2만원: ___개
# 2만원~4만원: ___개
# 4만원 이상: ___개
# 합계: ___개
# ```
#
# **빈칸 힌트**: 코드 셀의 `____`를 채우는 방식으로 접근한다. 사용할 데이터, 조건식, 함수명은 강의 노트의 같은 개념 예제를 찾아 직접 선택한다.

# %%
# 빈칸 가이드: 대상, 함수명, 조건식, 출력값을 직접 채우세요.
# 대상 = ____
# 결과 = ____(대상, ____)
# print(____)

# %% [markdown]
# ---
#
# ## 문제 14 — 기온과 걸음 수 관계 보기
#
# 같은 90일의 `temp` 와 `steps` 를 이용해 기온과 걸음 수의 상관계수를 계산한다.
#
# 해야 할 일:
#
# 1. `np.corrcoef(temp, steps)[0, 1]` 로 상관계수를 구한다.
# 2. 값이 0.3보다 크면 "양의 상관", -0.3보다 작으면 "음의 상관", 그 사이면 "약한 상관"으로 출력한다.
# 3. 상관계수 숫자와 해석을 함께 출력한다.
#
# **빈칸 힌트**: 코드 셀의 `____`를 채우는 방식으로 접근한다. 사용할 데이터, 조건식, 함수명은 강의 노트의 같은 개념 예제를 찾아 직접 선택한다.

# %%
# 빈칸 가이드: 대상, 함수명, 조건식, 출력값을 직접 채우세요.
# 대상 = ____
# 결과 = ____(대상, ____)
# print(____)

# %% [markdown]
# ---
#
# ## 문제 15 — 한 페이지 분석 결론 만들기
#
# 지금까지 계산한 값 중 최소 4개를 사용해 짧은 분석 결론을 만든다.
#
# 먼저 코드 셀에서 결론에 쓸 핵심 숫자를 다시 출력한다.
#
# - 점수 평균과 표준편차
# - 10,000보 달성률
# - 평일/주말 평균 차이
# - 기온-걸음 상관계수
# - 가격 평균과 중앙값 차이
#
# 그 다음 마크다운 셀에 결론 4줄을 작성한다.
#
# **빈칸 힌트**: 코드 셀의 `____`를 채우는 방식으로 접근한다. 사용할 데이터, 조건식, 함수명은 강의 노트의 같은 개념 예제를 찾아 직접 선택한다.

# %%
# 빈칸 가이드: 대상, 함수명, 조건식, 출력값을 직접 채우세요.
# 대상 = ____
# 결과 = ____(대상, ____)
# print(____)

# %% [markdown]
# ## 결론
#
# 1. 점수 데이터:
# 2. 걸음 데이터:
# 3. 기온과 걸음 관계:
# 4. 가격 데이터:
#
# ---
#
# ## 제출 전 자가 점검표
#
# 아래 항목을 스스로 확인한 뒤 강사에게 제출한다. 이 표는 정답을 알려주기 위한 것이 아니라, 노트북이 분석 보고서처럼 읽히는지 확인하기 위한 체크리스트다.
#
# | 문제 | 자가 점검 질문 |
# |---:|---|
# | 1 | `scores.csv` 를 헤더 없이 숫자 배열로 불러왔는가? 학생 수, 평균, 중앙값, 표준편차가 모두 출력되는가? |
# | 2 | 90점 이상과 60점 미만 조건을 각각 Boolean mask로 만들었는가? 명수와 비율을 둘 다 출력했는가? |
# | 3 | Q1, Q2, Q3를 한 번에 계산했는가? IQR이 `Q3 - Q1` 로 계산되었는가? |
# | 4 | A/B/C/D/F 등급 구간이 서로 겹치지 않는가? 마지막 합계가 전체 학생 수와 같은가? |
# | 5 | z-score를 만들 때 평균을 빼고 표준편차로 나누었는가? `np.abs` 로 높은 쪽과 낮은 쪽을 모두 확인했는가? |
# | 6 | `daily_steps.csv` 의 첫 번째 열을 일자, 두 번째 열을 걸음 수로 나누었는가? `argmax` 위치와 실제 일자를 구분했는가? |
# | 7 | 10,000보 이상과 5,000보 미만 조건을 각각 만들었는가? 낮은 활동일은 걸음 수가 아니라 일자 리스트로 출력했는가? |
# | 8 | 90일을 30일씩 정확히 세 구간으로 나누었는가? 변화 방향을 숫자 근거와 함께 출력했는가? |
# | 9 | `(day - 1) % 7` 로 요일 번호를 만들었는가? 주말 조건을 `(dow == 5) | (dow == 6)` 처럼 괄호로 묶었는가? |
# | 10 | 기온 데이터에서도 평균, 중앙값, 표준편차, 분위수, IQR을 모두 출력했는가? |
# | 11 | `10 <= temp <= 15` 처럼 쓰지 않고 `(temp >= 10) & (temp <= 15)` 형태로 작성했는가? |
# | 12 | 평균 가격과 중앙값 가격을 비교할 수 있게 둘 다 출력했는가? 천 단위 콤마를 붙이면 더 읽기 좋은가? |
# | 13 | 네 가격 구간이 서로 겹치지 않는가? 마지막 합계가 전체 상품 수와 같은가? |
# | 14 | 기온 배열과 걸음 배열이 같은 90일 순서인지 확인했는가? 상관계수 값과 해석을 함께 출력했는가? |
# | 15 | 결론 4줄에 실제 코드 출력 숫자가 들어갔는가? 숫자만 적지 않고 의미까지 해석했는가? |
#
# ### 제출 전에 지워도 되는 것과 지우면 안 되는 것
#
# - 지워도 되는 것: 연습 과정에서 만든 임시 출력, 실패했던 코드 셀, 중복으로 실행한 테스트 셀.
# - 지우면 안 되는 것: 환경 셀, 각 문제의 최종 코드 셀, 문제 15의 결론 마크다운 셀.
# - 코드가 길어졌다면 변수명을 짧게 줄이는 것보다, 한 줄 주석으로 의도를 남기는 편이 좋다.
# - 에러가 남아 있는 셀은 제출 전 반드시 정리한다. 노트북을 위에서부터 다시 실행했을 때 같은 결과가 나와야 한다.
#
# ### 강사에게 질문할 때 준비할 것
#
# 질문하기 전에 다음 3가지를 같이 보여주면 피드백이 빨라진다.
#
# 1. 문제가 되는 코드 셀 전체.
# 2. 에러 메시지 전체 또는 이상하게 나온 출력.
# 3. 내가 기대했던 결과 형태.
#
# 예를 들어 "문제 9가 안 돼요" 라고만 말하면 원인을 찾기 어렵다. 대신 "`weekend_mask` 를 만들었는데 평일/주말 일수 합이 90이 안 됩니다" 처럼 말하면 강사가 바로 마스크 조건을 확인해줄 수 있다.
#
# 제출 전 마지막으로 `Kernel` 또는 `Runtime` 메뉴에서 노트북을 처음부터 다시 실행한다. 중간 셀을 지웠거나 순서가 꼬였으면 이전에는 보이던 변수가 사라질 수 있다. 처음부터 다시 실행해도 끝까지 통과하는 노트북만 제출한다.
#
# ---
#
# ## 다 끝낸 학생
#
# - 모든 문제가 정상 실행됐다면 `final-mission.ipynb` 로 이동한다.
# - 노트북을 PC에 다운받아 강사가 지정한 위치에 제출한다.
# - 다음 수업까지 최종 미션을 마무리해온다.
