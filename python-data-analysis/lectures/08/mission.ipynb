# %% [markdown]
# # 레슨 08 — 실습 미션
#
# 이번 미션은 시각화 기초: matplotlib · seaborn 연습이다. 정답값은 적지 말고 직접 실행 결과로 확인한다.
#
# ## 환경 셀

# %%
import os
import pandas as pd
import numpy as np

IS_COLAB = "COLAB_GPU" in os.environ or "COLAB_TPU_ADDR" in os.environ
DATA_BASE = "./data"
print("data base:", DATA_BASE)

# %% [markdown]
# ---
#
# ## 미션 1. 데이터 첫 점검
#
# **요구사항**
#
# 1. 파일을 읽고 `shape`, `head`, `info` 를 확인한다.
# 2. 결과 표의 앞부분을 출력한다.
# 3. 계산 기준을 주석으로 한 줄 적는다.
# 4. 에러가 나면 `columns` 와 `dtypes` 를 먼저 확인한다.

# %%
# 미션 1
# 여기에 코드 작성
pass

# %% [markdown]
# ---
#
# ## 미션 2. 핵심 처리 1
#
# **요구사항**
#
# 1. 이번 레슨 도구 중 앞부분을 사용해 채널별 주문·매출·광고비 데이터 의 구조를 정리한다.
# 2. 결과 표의 앞부분을 출력한다.
# 3. 계산 기준을 주석으로 한 줄 적는다.
# 4. 에러가 나면 `columns` 와 `dtypes` 를 먼저 확인한다.

# %%
# 미션 2
# 여기에 코드 작성
pass

# %% [markdown]
# ---
#
# ## 미션 3. 핵심 처리 2
#
# **요구사항**
#
# 1. 중간 표를 만들고 행 수, 열 이름, 요약 통계를 확인한다.
# 2. 결과 표의 앞부분을 출력한다.
# 3. 계산 기준을 주석으로 한 줄 적는다.
# 4. 에러가 나면 `columns` 와 `dtypes` 를 먼저 확인한다.

# %%
# 미션 3
# 여기에 코드 작성
pass

# %% [markdown]
# ---
#
# ## 미션 4. 요약 표 만들기
#
# **요구사항**
#
# 1. 분석 목적에 맞는 집계 또는 비교 표를 만든다.
# 2. 결과 표의 앞부분을 출력한다.
# 3. 계산 기준을 주석으로 한 줄 적는다.
# 4. 에러가 나면 `columns` 와 `dtypes` 를 먼저 확인한다.

# %%
# 미션 4
# 여기에 코드 작성
pass

# %% [markdown]
# ---
#
# ## 미션 5. 결론 작성
#
# **요구사항**
#
# 1. `인사이트 5개 + 차트 5종 발표 자료` 에 들어갈 핵심 문장을 작성한다.
# 2. 결과 표의 앞부분을 출력한다.
# 3. 계산 기준을 주석으로 한 줄 적는다.
# 4. 에러가 나면 `columns` 와 `dtypes` 를 먼저 확인한다.

# %%
# 미션 5
# 여기에 코드 작성
pass

# %%
# %%markdown
# ## 결론
#
# (핵심 숫자 1개, 비교 대상 1개, 다음 행동 1개를 포함해 작성)

# %% [markdown]
# ## 보너스 미션
#
# - B1: 분석 기준을 하나 더 추가해 비교 표를 만든다.
# - B2: 결과를 CSV 로 저장하거나 차트로 표현한다.
# - B3: 결론 문장을 발표용 3줄 요약으로 바꾼다.
#
# ## 제출 전 체크
#
# - [ ] 모든 코드 셀이 위에서 아래로 실행된다.
# - [ ] 학생용 노트북에 정답지를 붙여넣지 않았다.
# - [ ] 결론이 코드 출력과 일치한다.

# %% [markdown]
# ## 미션별 채점 기준
#
# | 구분 | 통과 기준 |
# |---|---|
# | 데이터 로드 | 파일 경로가 상대 경로 또는 `DATA_BASE` 기준으로 되어 있음 |
# | 구조 확인 | `shape`, `columns`, `head`, `info` 중 2개 이상 사용 |
# | 핵심 처리 | `subplots, lineplot, barplot, histplot, boxplot, scatterplot, heatmap` 중 수업 핵심 도구를 실제 데이터에 적용 |
# | 검증 | 중간 결과의 행 수나 앞부분을 출력 |
# | 결론 | `인사이트 5개 + 차트 5종 발표 자료` 에 맞는 숫자와 비교가 들어 있음 |
#
# ## 힌트 모음
#
# - 파일이 안 열리면 코드보다 경로부터 확인한다.
# - 열 이름이 기억나지 않으면 `df.columns` 를 출력한다.
# - 결과가 비어 있으면 조건을 하나씩 줄여 본다.
# - 새 열을 만들었으면 `head()` 로 손계산 가능한 몇 행을 확인한다.
# - 결론을 쓰기 전 마지막 출력 셀을 다시 실행한다.
#
# ## 좋은 제출 예시의 특징
#
# 좋은 제출물은 코드가 길지 않아도 흐름이 선명하다. 셀마다 무엇을 확인하는지 보이고, 중간 표 이름이 의미 있으며, 마지막 결론이 코드 출력과 맞는다. 반대로 함수는 많이 썼지만 경로가 절대경로이고 결론이 비어 있으면 미완성으로 본다.
#
# ## 오답을 줄이는 작성 순서
#
# 1. 미션 요구사항을 주석으로 먼저 복사한다.
# 2. 각 주석 아래에 코드 한두 줄만 작성한다.
# 3. 결과를 출력해 눈으로 확인한다.
# 4. 다음 요구사항으로 넘어간다.
#
# 한 셀에 모든 코드를 몰아넣으면 어느 단계에서 틀렸는지 찾기 어렵다. 이번 미션은 정확한 중간 확인을 연습하는 과제다.
#
# ## 최소 제출 기준
#
# 시간이 부족한 학생도 미션 1, 미션 2, 결론 셀은 반드시 채운다. 미션 3~5가 일부 비어 있더라도 첫 점검과 핵심 처리 방향을 설명할 수 있으면 보충 지도가 가능하다.
#
# 미션을 모두 끝낸 뒤에는 노트북을 저장하기 전에 실행 순서를 다시 확인한다.
#
# ## 품질 보강 노트
#
# - `시각화 기초: matplotlib · seaborn` 에서는 빠른 정답보다 기준을 말할 수 있는 코드가 중요하다. 중간 표가 무엇을 의미하는지 한 문장으로 설명하지 못하면, 다음 셀로 넘어가기 전에 변수명과 출력 라벨을 고친다.
